# %%
#coding=utf8

import pandas as pd 
import numpy as np 
import matplotlib#导入计算图像化库
import matplotlib.pyplot as plt#导入图像生成器
from matplotlib import font_manager#导入字体管理器
from matplotlib import rcParams#导入matplotlib参数设置器
#导入notebook图像显示（#不可写在%号后面）
# %matplotlib inline

df=pd.read_csv("/Users/chengang/Desktop/merged_data.csv",error_bad_lines=False)#导入csv数据，忽略错误行
#print df.head()#查看文件标头
#df.tail()#查看文件末尾
#df.describe()#查看文件描述
#df.index
#df.values
#df.to_csv("merged_data.csv")#保存清洗后的数据到csv文件
#df.iloc[:,-2]#定位到所有行的倒数第2列
#df.iloc[:,-2].value_counts()#统计此列所有值
#df.iloc[:,-2].value_counts().plot()#图形化显示
#df.iloc[:,-2].value_counts().plot(kind='bar')#设定图形形状柱形图
#df.iloc[:,-2].value_counts().plot(kind='bar').get_figure().savefig('/Users/chengang/Desktop/tt.png')#保存图片
#df.iloc[:,-2].value_counts().hist()#直方图

#dates = pd.date_range('20150101', periods= 300)#生成随机Series
#df1 = pd.DataFrame(np.random.randn(300,4), index=dates, columns=list('ABCD'))#生成随机DataFrame
#df1.plot(kind='scatter',x="A", y="B", alpha=0.3)#生成散列图，查看数据重复状况，alpha设定透明度。

#rcParams['savefig.dpi']=100#设定图片的DPI
#fig = plt.figure()#定义一个图片
#ax = fig.add_subplot(111)#划分1行1列选第1块。  
#x = ax.xaxis#获取x,y轴坐标
#y = ax.yaxis
#xmajorLocator = matplotlib.ticker.MultipleLocator(1)#设定主 X 轴间隔为1的倍数
#x.set_major_locator(xmajorLocator)
#ax.set_xticklabels("abcdefg",fontproperties=zhfont2)#设定 X 轴坐标标签
#df.iloc[:,-2].value_counts().iloc[1:15].plot(color=(0,0,1),marker='o')#图形化显示，选定RGB颜色，选定标记为点

#setFont= matplotlib.font_manager.FontProperties(fname='/Library/Fonts/Hanzipen.ttc')#设定中文字体
#setFont1= font_manager.FontProperties(fname='/Library/Fonts/Lantinghei.ttc')
#setFont2= font_manager.FontProperties(fname='/Library/Fonts/Yuanti.ttc')

#plt.title(u"我是标题", fontproperties = setFont, size = 30)#设定图片标头及其属性
#plt.xlabel(u"我是X轴标签",fontproperties = setFont, size =12)#设定横轴标签
#plt.ylabel(u"我是Y轴标签",fontproperties = setFont, size =12)#设定纵轴标签

#plt.legend((u"看这里",), 'lower right',prop=setFont)#设定图素标签

# %%
#测试生成随机散列图，来检查数据的重复状况，颜色越浓说明数据重复越高。
dates = pd.date_range('20150101', periods= 300)
df1 = pd.DataFrame(np.random.randn(300,4), index=dates, columns=list('ABCD'))
df1.plot(kind='scatter',x="A", y="B", alpha=0.3)

# %%
df.iloc[:,-2].value_counts().iloc[1:15]
# Out:
# 浙江    796
# 广东    786
# 深圳    472
# 广州    374
# 长沙    294
# 上海    217
# 北京    212
# 杭州    199
# 烟台    189
# 武汉    187
# 江苏    185
# 重庆    179
# 东莞    161
# 福建    161
# dtype: int64

# %%
rcParams['savefig.dpi']=100#设定图片的DPI
zhfont1= font_manager.FontProperties(fname='/Library/Fonts/Lantinghei.ttc')
zhfont2= font_manager.FontProperties(fname='/Library/Fonts/Hanzipen.ttc')
zhfont3= font_manager.FontProperties(fname='/Library/Fonts/Yuanti.ttc')
fig = plt.figure()#定义一个图片
ax = fig.add_subplot(111)#划分1行1列选第1块。  
x = ax.xaxis#获取 x 轴坐标
y = ax.yaxis#获取 y 轴坐标
xmajorLocator = matplotlib.ticker.MultipleLocator(1)#设定主 X 轴间隔为1的倍数
x.set_major_locator(xmajorLocator)
ax.set_xticklabels("abcdefg",fontproperties=zhfont2)#设定 X 轴坐标标签
df.iloc[:,-2].value_counts().iloc[1:15].plot(color=(0,0,1),marker='o')#图形化显示，选定RGB颜色，选定标记为点
plt.title(u"逗你玩威客网站数据分析",fontproperties=zhfont2,size=15)
#plt.text(0.5,0.5,u"北国风光",fontproperties=zhfont2,size=30) 
plt.xlabel(u"任务源所在地区",fontproperties=zhfont2,size=12)
plt.ylabel(u"任务数量",fontproperties=zhfont2,size=12)
plt.legend((u"任务数量",), loc='upper right',prop=zhfont2)

# %%
df.iloc[:,-1].value_counts().iloc[1:15]
# Out:
# 温州    545
# 深圳    209
# 广州    173
# 东莞     95
# 杭州     85
# 成都     59
# 武汉     57
# 厦门     55
# 南京     51
# 苏州     51
# 宁波     42
# 福州     42
# 嘉兴     40
# 郑州     39
# dtype: int64

# %%
fig = plt.figure()#定义一个图片
ax = fig.add_subplot(111)#划分1行1列选第1块。  
x = ax.xaxis#获取x,y轴坐标
y = ax.yaxis
xmajorLocator = matplotlib.ticker.MultipleLocator(1)#设定主 X 轴间隔为1的倍数
x.set_major_locator(xmajorLocator)
ax.set_xticklabels("abcdefg",fontproperties=zhfont2)#设定 X 轴坐标标签

df.iloc[:,-1].value_counts().iloc[1:15].plot(color=(0,0,1),marker='o')#图形化显示，选定RGB颜色，选定标记为点

plt.title(u"逗你玩威客网站数据分析",fontproperties=zhfont2,size=15)
#plt.text(0.5,0.5,u"北国风光",fontproperties=zhfont2,size=30) 
plt.xlabel(u"任务源所在地区",fontproperties=zhfont2,size=12)
plt.ylabel(u"任务数量",fontproperties=zhfont2,size=12)
plt.legend((u"任务数量",), loc='upper right',prop=zhfont2)
